# %% [markdown]
# # Análise de sobre o valor de frete praticado em diferentes regiões

# %% [markdown]
# ## Dúvida da área de negócios
# * **Existe diferença no valor do frete praticado em regiões/cidades diferentes? Ou podemos aplicar as mesmas regras de subsídio de frete para qualquer localidade?**
#
# * **Resposta:**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.offline as py
import plotly.graph_objs as go
from datetime import datetime

# %%
# %matplotlib inline

from IPython.core.pylabtools import figsize


figsize(12, 8)

sns.set()

# %% [markdown]
# ## Carregando bases de dados

# %%
df_customers = pd.read_csv('../datasets/olist_customers_dataset.csv', encoding='ISO-8859-1')
df_geolocation = pd.read_csv('../datasets/olist_geolocation_dataset.csv', encoding='ISO-8859-1')
df_order_items = pd.read_csv('../datasets/olist_order_items_dataset.csv', encoding='ISO-8859-1')
df_order_payments = pd.read_csv('../datasets/olist_order_payments_dataset.csv', encoding='ISO-8859-1')
df_order_reviews = pd.read_csv('../datasets/olist_order_reviews_dataset.csv', encoding='ISO-8859-1')
df_orders = pd.read_csv('../datasets/olist_orders_dataset.csv', encoding='ISO-8859-1')
df_products = pd.read_csv('../datasets/olist_products_dataset.csv', encoding='ISO-8859-1')
df_sellers = pd.read_csv('../datasets/olist_sellers_dataset.csv', encoding='ISO-8859-1')
df_product_category_name_translation = pd.read_csv('../datasets/product_category_name_translation.csv', encoding='ISO-8859-1')

# %% [markdown]
# ## Base de Clientes

# %%
df_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# ## Base de Lojistas

# %%
df_sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ## Base de Geolocalizações

# %%
df_geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# ## Base de Pedidos

# %%
df_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %% [markdown]
# ## Itens do pedido

# %%
df_order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %% [markdown]
# ## Forma de pagamento de cada pedido

# %%
df_order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# ## Retorno de clientes sobre a compra realizada

# %%
df_order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  ParabÃ©ns lojas lannister adorei comprar pela ...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %% [markdown]
# ## Dados cadastrais de cada produto

# %%
df_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %% [markdown]
# ## Tradução das categorias de produtos

# %%
df_product_category_name_translation.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
df_orders_freight_value = pd.DataFrame(columns=['customer_id', 'order_id', 'freight_value', 'customer_zip_code_prefix', 'customer_city', 'customer_state'])

# %%
for customer_id in df_orders[df_orders['order_status'] == 'delivered']['customer_id']:
    order_id = df_orders[df_orders['customer_id'] == customer_id]['order_id'].unique()[0]
    freight_value = df_order_items[(df_order_items['order_id'] == order_id) & (df_order_items['order_item_id'] == 1)]['freight_value'].values[0]
    customer_zip_code_prefix = df_customers[df_customers['customer_id'] == customer_id]['customer_zip_code_prefix'].values[0]
    customer_city = df_customers[df_customers['customer_id'] == customer_id]['customer_city'].values[0]
    customer_state = df_customers[df_customers['customer_id'] == customer_id]['customer_state'].values[0]
    
    df_orders_freight_value =  df_orders_freight_value.append({'customer_id':customer_id,
                                                               'order_id':order_id,
                                                               'freight_value':freight_value,
                                                               'customer_zip_code_prefix':customer_zip_code_prefix,
                                                               'customer_city':customer_city,
                                                               'customer_state':customer_state}, ignore_index=True)

# %%
df_orders_freight_value[df_orders_freight_value['customer_state']=='SP']
# Out:
#                             customer_id                          order_id  \
# 0      9ef432eb6251297304e76186b10a928d  e481f51cbdc54678b7cc49136f2d6af7
# 4      8ab97904e6daea8866dbdbc4fb7aad2c  ad21c59c0840e6cb83a9ceb5573f8159
# 31             14.10                     5778              sao paulo
# 33              9.41                    13454  santa barbara d'oeste
# 36             15.10                    19780                  quata
# 38             12.79                     4561              sao paulo
# 40             17.12                    19400   presidente venceslau
# 45             12.43                    12230    sao jose dos campos
# 47             15.56                     1038              sao paulo
# 48             13.37                     6330            carapicuiba
# 52             11.85                    12070                taubate
# 54             13.47                     3942              sao paulo
# 56             14.36                    13068               campinas
# 57             28.15                     4658              sao paulo
# 58             11.76                     8280              sao paulo
# 65             13.25                     8220              sao paulo
# 66             12.03                    13157             cosmopolis
# 68              9.34                     2346              sao paulo
# ...              ...                      ...                    ...
# 96419           7.39                     5368              sao paulo
# 96421           9.69                     9320                   maua
# 96423          37.04                     2611              sao paulo
# 96424          19.93                    15041  sao jose do rio preto
# 96425           9.44                     2050              sao paulo
# 96428          17.14                    15993                  matao
# 96433           8.97                     6449                barueri
# 96434          24.75                     9330                   maua
# 96435          19.63                     3122              sao paulo
# 96436          17.06                     3445              sao paulo
# 96438          11.85                     4520              sao paulo
# 96439          10.78                     5175              sao paulo
# 96440          11.85                    11320            sao vicente
# 96443           7.94                     9951                diadema
# 96444          20.73                    13520              sao pedro
# 96445          12.88                     1454              sao paulo
# 96447          27.26                     2042              sao paulo
# 96449          13.41                     6428                barueri
# 96450          12.40                    13490          cordeiropolis
# 96452          18.12                     3318              sao paulo
# 96453          16.21                    13820             jaguariuna
# 96456          11.85                    11320            sao vicente
# 96460          11.85                    14802             araraquara
# 96462          36.86                    13272               valinhos
# 96464           8.79                     8550                    poa
# 96465          16.06                    13218                jundiai
# 96466           9.94                     1308              sao paulo
# 96472          16.09                     5127              sao paulo
# 96473          13.08                    12209    sao jose dos campos
# 96474          20.10                    11722           praia grande
#
#       customer_state
# 0                 SP
# 4                 SP
# 8                 SP
# 10                SP
# 12                SP
# 13                SP
# 17                SP
# 19                SP
# 20                SP
# 21                SP
# 23                SP
# 26                SP
# 27                SP
# 29                SP
# 31                SP
# 33                SP
# 36                SP
# 38                SP
# 40                SP
# 45                SP
# 47                SP
# 48                SP
# 52                SP
# 54                SP
# 56                SP
# 57                SP
# 58                SP
# 65                SP
# 66                SP
# 68                SP
# ...              ...
# 96419             SP
# 96421             SP
# 96423             SP
# 96424             SP
# 96425             SP
# 96428             SP
# 96433             SP
# 96434             SP
# 96435             SP
# 96436             SP
# 96438             SP
# 96439             SP
# 96440             SP
# 96443             SP
# 96444             SP
# 96445             SP
# 96447             SP
# 96449             SP
# 96450             SP
# 96452             SP
# 96453             SP
# 96456             SP
# 96460             SP
# 96462             SP
# 96464             SP
# 96465             SP
# 96466             SP
# 96472             SP
# 96473             SP
# 96474             SP
#
# [40501 rows x 6 columns]

# %%
df_orders_freight_value.to_csv('../datasets/df_orders_freight_value.csv')

# %%
round(df_orders_freight_value['freight_value'].mean(),2)
# Out:
# 20.16

# %%
round(df_orders_freight_value['freight_value'].std(),2)
# Out:
# 15.8

# %%
round(df_orders_freight_value['freight_value'].var(),2)
# Out:
# 249.68

# %%
sns.regplot(data=df_orders_freight_value, x='customer_zip_code_prefix', y='freight_value', color="black")
